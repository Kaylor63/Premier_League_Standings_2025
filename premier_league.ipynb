# %% [markdown]
# Premier League Standings

# %%
import os
import json
import requests
import pandas as pandas
from mysql import connector
import mysql.connector as connector
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
API_KEY = os.getenv("API_KEY")
API_HOST = os.getenv("API_HOST")
SEASON = 2025
LEAGUE_ID = 39

# %%
url = "https://premier-league-standings1.p.rapidapi.com/"

headers = {
	"x-rapidapi-key": API_KEY,
	"x-rapidapi-host": API_HOST
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# [{'team': {'name': 'Liverpool', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/364.png', 'abbreviation': 'LIV'}, 'stats': {'wins': 4, 'losses': 0, 'ties': 0, 'gamesPlayed': 4, 'goalsFor': 9, 'goalsAgainst': 4, 'points': 12, 'rank': 1, 'goalDifference': 5}}, {'team': {'name': 'Arsenal', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/359.png', 'abbreviation': 'ARS'}, 'stats': {'wins': 3, 'losses': 1, 'ties': 0, 'gamesPlayed': 4, 'goalsFor': 9, 'goalsAgainst': 1, 'points': 9, 'rank': 2, 'goalDifference': 8}}, {'team': {'name': 'Tottenham Hotspur', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/367.png', 'abbreviation': 'TOT'}, 'stats': {'wins': 3, 'losses': 1, 'ties': 0, 'gamesPlayed': 4, 'goalsFor': 8, 'goalsAgainst': 1, 'points': 9, 'rank': 3, 'goalDifference': 7}}, {'team': {'name': 'AFC Bournemouth', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/349.png', 'abbreviation': 'BOU'}, 'stats': {'wins': 3, 'losses': 1, 'ties': 0, 'gamesPlayed': 4, 'goalsFor': 6, 'goalsAgainst': 5, 'points': 9, 'rank': 4, 'goalDifference': 1}}, {'team': {'name': 'Chelsea', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/363.png', 'abbreviation': 'CHE'}, 'stats': {'wins': 2, 'losses': 0, 'ties': 2, 'gamesPlayed': 4, 'goalsFor': 9, 'goalsAgainst': 3, 'points': 8, 'rank': 5, 'goalDifference': 6}}, {'team': {'name': 'Everton', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/368.png', 'abbreviation': 'EVE'}, 'stats': {'wins': 2, 'losses': 1, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 5, 'goalsAgainst': 3, 'points': 7, 'rank': 6, 'goalDifference': 2}}, {'team': {'name': 'Sunderland', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/366.png', 'abbreviation': 'SUN'}, 'stats': {'wins': 2, 'losses': 1, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 5, 'goalsAgainst': 3, 'points': 7, 'rank': 7, 'goalDifference': 2}}, {'team': {'name': 'Manchester City', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png', 'abbreviation': 'MNC'}, 'stats': {'wins': 2, 'losses': 2, 'ties': 0, 'gamesPlayed': 4, 'goalsFor': 8, 'goalsAgainst': 4, 'points': 6, 'rank': 8, 'goalDifference': 4}}, {'team': {'name': 'Crystal Palace', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/384.png', 'abbreviation': 'CRY'}, 'stats': {'wins': 1, 'losses': 0, 'ties': 3, 'gamesPlayed': 4, 'goalsFor': 4, 'goalsAgainst': 1, 'points': 6, 'rank': 9, 'goalDifference': 3}}, {'team': {'name': 'Newcastle United', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/361.png', 'abbreviation': 'NEW'}, 'stats': {'wins': 1, 'losses': 1, 'ties': 2, 'gamesPlayed': 4, 'goalsFor': 3, 'goalsAgainst': 3, 'points': 5, 'rank': 10, 'goalDifference': 0}}, {'team': {'name': 'Fulham', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/370.png', 'abbreviation': 'FUL'}, 'stats': {'wins': 1, 'losses': 1, 'ties': 2, 'gamesPlayed': 4, 'goalsFor': 3, 'goalsAgainst': 4, 'points': 5, 'rank': 11, 'goalDifference': -1}}, {'team': {'name': 'Brentford', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/337.png', 'abbreviation': 'BRE'}, 'stats': {'wins': 1, 'losses': 2, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 5, 'goalsAgainst': 7, 'points': 4, 'rank': 12, 'goalDifference': -2}}, {'team': {'name': 'Brighton & Hove Albion', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/331.png', 'abbreviation': 'BHA'}, 'stats': {'wins': 1, 'losses': 2, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 4, 'goalsAgainst': 6, 'points': 4, 'rank': 13, 'goalDifference': -2}}, {'team': {'name': 'Manchester United', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/360.png', 'abbreviation': 'MAN'}, 'stats': {'wins': 1, 'losses': 2, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 4, 'goalsAgainst': 7, 'points': 4, 'rank': 14, 'goalDifference': -3}}, {'team': {'name': 'Nottingham Forest', 'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/393.png', 'abbreviation': 'NFO'}, 'stats': {'wins': 1, 'losses': 2, 'ties': 1, 'gamesPlayed': 4, 'goalsFor': 4, 'goalsAgainst': 8, 'points': 4, 'rank': 15, 'goalDifferen ...

# %% [markdown]
# EXTRACT

# %%
response = requests.get(url, headers=headers )

# %%
payload = response.json()

# %%
payload
# Out:
# [{'team': {'name': 'Liverpool',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/364.png',
#    'abbreviation': 'LIV'},
#   'stats': {'wins': 4,
#    'losses': 0,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 9,
#    'goalsAgainst': 4,
#    'points': 12,
#    'rank': 1,
#    'goalDifference': 5}},
#  {'team': {'name': 'Arsenal',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/359.png',
#    'abbreviation': 'ARS'},
#   'stats': {'wins': 3,
#    'losses': 1,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 9,
#    'goalsAgainst': 1,
#    'points': 9,
#    'rank': 2,
#    'goalDifference': 8}},
#  {'team': {'name': 'Tottenham Hotspur',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/367.png',
#    'abbreviation': 'TOT'},
#   'stats': {'wins': 3,
#    'losses': 1,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 8,
#    'goalsAgainst': 1,
#    'points': 9,
#    'rank': 3,
#    'goalDifference': 7}},
#  {'team': {'name': 'AFC Bournemouth',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/349.png',
#    'abbreviation': 'BOU'},
#   'stats': {'wins': 3,
#    'losses': 1,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 6,
#    'goalsAgainst': 5,
#    'points': 9,
#    'rank': 4,
#    'goalDifference': 1}},
#  {'team': {'name': 'Chelsea',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/363.png',
#    'abbreviation': 'CHE'},
#   'stats': {'wins': 2,
#    'losses': 0,
#    'ties': 2,
#    'gamesPlayed': 4,
#    'goalsFor': 9,
#    'goalsAgainst': 3,
#    'points': 8,
#    'rank': 5,
#    'goalDifference': 6}},
#  {'team': {'name': 'Everton',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/368.png',
#    'abbreviation': 'EVE'},
#   'stats': {'wins': 2,
#    'losses': 1,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 5,
#    'goalsAgainst': 3,
#    'points': 7,
#    'rank': 6,
#    'goalDifference': 2}},
#  {'team': {'name': 'Sunderland',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/366.png',
#    'abbreviation': 'SUN'},
#   'stats': {'wins': 2,
#    'losses': 1,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 5,
#    'goalsAgainst': 3,
#    'points': 7,
#    'rank': 7,
#    'goalDifference': 2}},
#  {'team': {'name': 'Manchester City',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png',
#    'abbreviation': 'MNC'},
#   'stats': {'wins': 2,
#    'losses': 2,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 8,
#    'goalsAgainst': 4,
#    'points': 6,
#    'rank': 8,
#    'goalDifference': 4}},
#  {'team': {'name': 'Crystal Palace',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/384.png',
#    'abbreviation': 'CRY'},
#   'stats': {'wins': 1,
#    'losses': 0,
#    'ties': 3,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 1,
#    'points': 6,
#    'rank': 9,
#    'goalDifference': 3}},
#  {'team': {'name': 'Newcastle United',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/361.png',
#    'abbreviation': 'NEW'},
#   'stats': {'wins': 1,
#    'losses': 1,
#    'ties': 2,
#    'gamesPlayed': 4,
#    'goalsFor': 3,
#    'goalsAgainst': 3,
#    'points': 5,
#    'rank': 10,
#    'goalDifference': 0}},
#  {'team': {'name': 'Fulham',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/370.png',
#    'abbreviation': 'FUL'},
#   'stats': {'wins': 1,
#    'losses': 1,
#    'ties': 2,
#    'gamesPlayed': 4,
#    'goalsFor': 3,
#    'goalsAgainst': 4,
#    'points': 5,
#    'rank': 11,
#    'goalDifference': -1}},
#  {'team': {'name': 'Brentford',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/337.png',
#    'abbreviation': 'BRE'},
#   'stats': {'wins': 1,
#    'losses': 2,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 5,
#    'goalsAgainst': 7,
#    'points': 4,
#    'rank': 12,
#    'goalDifference': -2}},
#  {'team': {'name': 'Brighton & Hove Albion',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/331.png',
#    'abbreviation': 'BHA'},
#   'stats': {'wins': 1,
#    'losses': 2,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 6,
#    'points': 4,
#    'rank': 13,
#    'goalDifference': -2}},
#  {'team': {'name': 'Manchester United',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/360.png',
#    'abbreviation': 'MAN'},
#   'stats': {'wins': 1,
#    'losses': 2,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 7,
#    'points': 4,
#    'rank': 14,
#    'goalDifference': -3}},
#  {'team': {'name': 'Nottingham Forest',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/393.png',
#    'abbreviation': 'NFO'},
#   'stats': {'wins': 1,
#    'losses': 2,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 8,
#    'points': 4,
#    'rank': 15,
#    'goalDifference': -4}},
#  {'team': {'name': 'Leeds United',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/357.png',
#    'abbreviation': 'LEE'},
#   'stats': {'wins': 1,
#    'losses': 2,
#    'ties': 1,
#    'gamesPlayed': 4,
#    'goalsFor': 1,
#    'goalsAgainst': 6,
#    'points': 4,
#    'rank': 16,
#    'goalDifference': -5}},
#  {'team': {'name': 'Burnley',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/379.png',
#    'abbreviation': 'BUR'},
#   'stats': {'wins': 1,
#    'losses': 3,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 7,
#    'points': 3,
#    'rank': 17,
#    'goalDifference': -3}},
#  {'team': {'name': 'West Ham United',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/371.png',
#    'abbreviation': 'WHU'},
#   'stats': {'wins': 1,
#    'losses': 3,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 4,
#    'goalsAgainst': 11,
#    'points': 3,
#    'rank': 18,
#    'goalDifference': -7}},
#  {'team': {'name': 'Aston Villa',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/362.png',
#    'abbreviation': 'AVL'},
#   'stats': {'wins': 0,
#    'losses': 2,
#    'ties': 2,
#    'gamesPlayed': 4,
#    'goalsFor': 0,
#    'goalsAgainst': 4,
#    'points': 2,
#    'rank': 19,
#    'goalDifference': -4}},
#  {'team': {'name': 'Wolverhampton Wanderers',
#    'logo': 'https://a.espncdn.com/i/teamlogos/soccer/500/380.png',
#    'abbreviation': 'WOL'},
#   'stats': {'wins': 0,
#    'losses': 4,
#    'ties': 0,
#    'gamesPlayed': 4,
#    'goalsFor': 2,
#    'goalsAgainst': 9,
#    'points': 0,
#    'rank': 20,
#    'goalDifference': -7}}]

# %%
formatted_payload = json.dumps(payload, indent=4)
print(formatted_payload)
# Out:
# [
#     {
#         "team": {
#             "name": "Liverpool",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/364.png",
#             "abbreviation": "LIV"
#         },
#         "stats": {
#             "wins": 4,
#             "losses": 0,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 9,
#             "goalsAgainst": 4,
#             "points": 12,
#             "rank": 1,
#             "goalDifference": 5
#         }
#     },
#     {
#         "team": {
#             "name": "Arsenal",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/359.png",
#             "abbreviation": "ARS"
#         },
#         "stats": {
#             "wins": 3,
#             "losses": 1,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 9,
#             "goalsAgainst": 1,
#             "points": 9,
#             "rank": 2,
#             "goalDifference": 8
#         }
#     },
#     {
#         "team": {
#             "name": "Tottenham Hotspur",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/367.png",
#             "abbreviation": "TOT"
#         },
#         "stats": {
#             "wins": 3,
#             "losses": 1,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 8,
#             "goalsAgainst": 1,
#             "points": 9,
#             "rank": 3,
#             "goalDifference": 7
#         }
#     },
#     {
#         "team": {
#             "name": "AFC Bournemouth",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/349.png",
#             "abbreviation": "BOU"
#         },
#         "stats": {
#             "wins": 3,
#             "losses": 1,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 6,
#             "goalsAgainst": 5,
#             "points": 9,
#             "rank": 4,
#             "goalDifference": 1
#         }
#     },
#     {
#         "team": {
#             "name": "Chelsea",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/363.png",
#             "abbreviation": "CHE"
#         },
#         "stats": {
#             "wins": 2,
#             "losses": 0,
#             "ties": 2,
#             "gamesPlayed": 4,
#             "goalsFor": 9,
#             "goalsAgainst": 3,
#             "points": 8,
#             "rank": 5,
#             "goalDifference": 6
#         }
#     },
#     {
#         "team": {
#             "name": "Everton",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/368.png",
#             "abbreviation": "EVE"
#         },
#         "stats": {
#             "wins": 2,
#             "losses": 1,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 5,
#             "goalsAgainst": 3,
#             "points": 7,
#             "rank": 6,
#             "goalDifference": 2
#         }
#     },
#     {
#         "team": {
#             "name": "Sunderland",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/366.png",
#             "abbreviation": "SUN"
#         },
#         "stats": {
#             "wins": 2,
#             "losses": 1,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 5,
#             "goalsAgainst": 3,
#             "points": 7,
#             "rank": 7,
#             "goalDifference": 2
#         }
#     },
#     {
#         "team": {
#             "name": "Manchester City",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/382.png",
#             "abbreviation": "MNC"
#         },
#         "stats": {
#             "wins": 2,
#             "losses": 2,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 8,
#             "goalsAgainst": 4,
#             "points": 6,
#             "rank": 8,
#             "goalDifference": 4
#         }
#     },
#     {
#         "team": {
#             "name": "Crystal Palace",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/384.png",
#             "abbreviation": "CRY"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 0,
#             "ties": 3,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 1,
#             "points": 6,
#             "rank": 9,
#             "goalDifference": 3
#         }
#     },
#     {
#         "team": {
#             "name": "Newcastle United",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/361.png",
#             "abbreviation": "NEW"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 1,
#             "ties": 2,
#             "gamesPlayed": 4,
#             "goalsFor": 3,
#             "goalsAgainst": 3,
#             "points": 5,
#             "rank": 10,
#             "goalDifference": 0
#         }
#     },
#     {
#         "team": {
#             "name": "Fulham",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/370.png",
#             "abbreviation": "FUL"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 1,
#             "ties": 2,
#             "gamesPlayed": 4,
#             "goalsFor": 3,
#             "goalsAgainst": 4,
#             "points": 5,
#             "rank": 11,
#             "goalDifference": -1
#         }
#     },
#     {
#         "team": {
#             "name": "Brentford",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/337.png",
#             "abbreviation": "BRE"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 2,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 5,
#             "goalsAgainst": 7,
#             "points": 4,
#             "rank": 12,
#             "goalDifference": -2
#         }
#     },
#     {
#         "team": {
#             "name": "Brighton & Hove Albion",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/331.png",
#             "abbreviation": "BHA"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 2,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 6,
#             "points": 4,
#             "rank": 13,
#             "goalDifference": -2
#         }
#     },
#     {
#         "team": {
#             "name": "Manchester United",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/360.png",
#             "abbreviation": "MAN"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 2,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 7,
#             "points": 4,
#             "rank": 14,
#             "goalDifference": -3
#         }
#     },
#     {
#         "team": {
#             "name": "Nottingham Forest",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/393.png",
#             "abbreviation": "NFO"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 2,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 8,
#             "points": 4,
#             "rank": 15,
#             "goalDifference": -4
#         }
#     },
#     {
#         "team": {
#             "name": "Leeds United",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/357.png",
#             "abbreviation": "LEE"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 2,
#             "ties": 1,
#             "gamesPlayed": 4,
#             "goalsFor": 1,
#             "goalsAgainst": 6,
#             "points": 4,
#             "rank": 16,
#             "goalDifference": -5
#         }
#     },
#     {
#         "team": {
#             "name": "Burnley",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/379.png",
#             "abbreviation": "BUR"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 3,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 7,
#             "points": 3,
#             "rank": 17,
#             "goalDifference": -3
#         }
#     },
#     {
#         "team": {
#             "name": "West Ham United",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/371.png",
#             "abbreviation": "WHU"
#         },
#         "stats": {
#             "wins": 1,
#             "losses": 3,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 4,
#             "goalsAgainst": 11,
#             "points": 3,
#             "rank": 18,
#             "goalDifference": -7
#         }
#     },
#     {
#         "team": {
#             "name": "Aston Villa",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/362.png",
#             "abbreviation": "AVL"
#         },
#         "stats": {
#             "wins": 0,
#             "losses": 2,
#             "ties": 2,
#             "gamesPlayed": 4,
#             "goalsFor": 0,
#             "goalsAgainst": 4,
#             "points": 2,
#             "rank": 19,
#             "goalDifference": -4
#         }
#     },
#     {
#         "team": {
#             "name": "Wolverhampton Wanderers",
#             "logo": "https://a.espncdn.com/i/teamlogos/soccer/500/380.png",
#             "abbreviation": "WOL"
#         },
#         "stats": {
#             "wins": 0,
#             "losses": 4,
#             "ties": 0,
#             "gamesPlayed": 4,
#             "goalsFor": 2,
#             "goalsAgainst": 9,
#             "points": 0,
#             "rank": 20,
#             "goalDifference": -7
#         }
#     }
# ]

# %%
standings_list = formatted_payload

# %%
formatted_standings_list = json.dumps(standings_list, indent=4)
print(f"\n\n\n{formatted_standings_list}")
# Out:
# "[\n    {\n        \"team\": {\n            \"name\": \"Liverpool\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/364.png\",\n            \"abbreviation\": \"LIV\"\n        },\n        \"stats\": {\n            \"wins\": 4,\n            \"losses\": 0,\n            \"ties\": 0,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 9,\n            \"goalsAgainst\": 4,\n            \"points\": 12,\n            \"rank\": 1,\n            \"goalDifference\": 5\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Arsenal\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/359.png\",\n            \"abbreviation\": \"ARS\"\n        },\n        \"stats\": {\n            \"wins\": 3,\n            \"losses\": 1,\n            \"ties\": 0,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 9,\n            \"goalsAgainst\": 1,\n            \"points\": 9,\n            \"rank\": 2,\n            \"goalDifference\": 8\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Tottenham Hotspur\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/367.png\",\n            \"abbreviation\": \"TOT\"\n        },\n        \"stats\": {\n            \"wins\": 3,\n            \"losses\": 1,\n            \"ties\": 0,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 8,\n            \"goalsAgainst\": 1,\n            \"points\": 9,\n            \"rank\": 3,\n            \"goalDifference\": 7\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"AFC Bournemouth\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/349.png\",\n            \"abbreviation\": \"BOU\"\n        },\n        \"stats\": {\n            \"wins\": 3,\n            \"losses\": 1,\n            \"ties\": 0,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 6,\n            \"goalsAgainst\": 5,\n            \"points\": 9,\n            \"rank\": 4,\n            \"goalDifference\": 1\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Chelsea\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/363.png\",\n            \"abbreviation\": \"CHE\"\n        },\n        \"stats\": {\n            \"wins\": 2,\n            \"losses\": 0,\n            \"ties\": 2,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 9,\n            \"goalsAgainst\": 3,\n            \"points\": 8,\n            \"rank\": 5,\n            \"goalDifference\": 6\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Everton\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/368.png\",\n            \"abbreviation\": \"EVE\"\n        },\n        \"stats\": {\n            \"wins\": 2,\n            \"losses\": 1,\n            \"ties\": 1,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 5,\n            \"goalsAgainst\": 3,\n            \"points\": 7,\n            \"rank\": 6,\n            \"goalDifference\": 2\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Sunderland\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/366.png\",\n            \"abbreviation\": \"SUN\"\n        },\n        \"stats\": {\n            \"wins\": 2,\n            \"losses\": 1,\n            \"ties\": 1,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 5,\n            \"goalsAgainst\": 3,\n            \"points\": 7,\n            \"rank\": 7,\n            \"goalDifference\": 2\n        }\n    },\n    {\n        \"team\": {\n            \"name\": \"Manchester City\",\n            \"logo\": \"https://a.espncdn.com/i/teamlogos/soccer/500/382.png\",\n            \"abbreviation\": \"MNC\"\n        },\n        \"stats\": {\n            \"wins\": 2,\n            \"losses\": 2,\n            \"ties\": 0,\n            \"gamesPlayed\": 4,\n            \"goalsFor\": 8,\n            \"goalsAgainst\": 4,\n            \"points\": 6,\n            \"rank\" ...

# %%
import json

# If standings_list is a JSON string, parse it first
if isinstance(standings_list, str):
    standings_list = json.loads(standings_list)

rows = []
column_names = [
    "season", "position", "team", "points",
    "all_played", "all_win", "all_draw", "all_lose",
    "all_goals_for", "all_goals_against", "goal_diff", "logo"
]

for club in standings_list:
    season = 2025
    rank = club['stats']['rank']
    team = club['team']['name']
    points = club['stats']['points']
    all_played = club['stats']['gamesPlayed']
    all_win = club['stats']['wins']
    all_draw = club['stats']['ties']
    all_lose = club['stats']['losses']
    all_goals_for = club['stats']['goalsFor']
    all_goals_against = club['stats']['goalsAgainst']
    goal_diff = club['stats']['goalDifference']
    logo = club['team']['logo']

    tuple_of_club_records = (season, rank, team, points, all_played, all_win, all_draw, all_lose, all_goals_for, all_goals_against, goal_diff, logo)
    rows.append(tuple_of_club_records)

# %%
print(rows)
# Out:
# [(2025, 1, 'Liverpool', 12, 4, 4, 0, 0, 9, 4, 5, 'https://a.espncdn.com/i/teamlogos/soccer/500/364.png'), (2025, 2, 'Arsenal', 9, 4, 3, 0, 1, 9, 1, 8, 'https://a.espncdn.com/i/teamlogos/soccer/500/359.png'), (2025, 3, 'Tottenham Hotspur', 9, 4, 3, 0, 1, 8, 1, 7, 'https://a.espncdn.com/i/teamlogos/soccer/500/367.png'), (2025, 4, 'AFC Bournemouth', 9, 4, 3, 0, 1, 6, 5, 1, 'https://a.espncdn.com/i/teamlogos/soccer/500/349.png'), (2025, 5, 'Chelsea', 8, 4, 2, 2, 0, 9, 3, 6, 'https://a.espncdn.com/i/teamlogos/soccer/500/363.png'), (2025, 6, 'Everton', 7, 4, 2, 1, 1, 5, 3, 2, 'https://a.espncdn.com/i/teamlogos/soccer/500/368.png'), (2025, 7, 'Sunderland', 7, 4, 2, 1, 1, 5, 3, 2, 'https://a.espncdn.com/i/teamlogos/soccer/500/366.png'), (2025, 8, 'Manchester City', 6, 4, 2, 0, 2, 8, 4, 4, 'https://a.espncdn.com/i/teamlogos/soccer/500/382.png'), (2025, 9, 'Crystal Palace', 6, 4, 1, 3, 0, 4, 1, 3, 'https://a.espncdn.com/i/teamlogos/soccer/500/384.png'), (2025, 10, 'Newcastle United', 5, 4, 1, 2, 1, 3, 3, 0, 'https://a.espncdn.com/i/teamlogos/soccer/500/361.png'), (2025, 11, 'Fulham', 5, 4, 1, 2, 1, 3, 4, -1, 'https://a.espncdn.com/i/teamlogos/soccer/500/370.png'), (2025, 12, 'Brentford', 4, 4, 1, 1, 2, 5, 7, -2, 'https://a.espncdn.com/i/teamlogos/soccer/500/337.png'), (2025, 13, 'Brighton & Hove Albion', 4, 4, 1, 1, 2, 4, 6, -2, 'https://a.espncdn.com/i/teamlogos/soccer/500/331.png'), (2025, 14, 'Manchester United', 4, 4, 1, 1, 2, 4, 7, -3, 'https://a.espncdn.com/i/teamlogos/soccer/500/360.png'), (2025, 15, 'Nottingham Forest', 4, 4, 1, 1, 2, 4, 8, -4, 'https://a.espncdn.com/i/teamlogos/soccer/500/393.png'), (2025, 16, 'Leeds United', 4, 4, 1, 1, 2, 1, 6, -5, 'https://a.espncdn.com/i/teamlogos/soccer/500/357.png'), (2025, 17, 'Burnley', 3, 4, 1, 0, 3, 4, 7, -3, 'https://a.espncdn.com/i/teamlogos/soccer/500/379.png'), (2025, 18, 'West Ham United', 3, 4, 1, 0, 3, 4, 11, -7, 'https://a.espncdn.com/i/teamlogos/soccer/500/371.png'), (2025, 19, 'Aston Villa', 2, 4, 0, 2, 2, 0, 4, -4, 'https://a.espncdn.com/i/teamlogos/soccer/500/362.png'), (2025, 20, 'Wolverhampton Wanderers', 0, 4, 0, 0, 4, 2, 9, -7, 'https://a.espncdn.com/i/teamlogos/soccer/500/380.png')]

# %%
df = pandas.DataFrame(rows, columns=column_names)

# %%
df.head(20)
# Out:
#     season  position                     team  points  all_played  all_win  \
# 0     2025         1                Liverpool      12           4        4
# 1     2025         2                  Arsenal       9           4        3
# 2     2025         3        Tottenham Hotspur       9           4        3
# 3     2025         4          AFC Bournemouth       9           4        3
# 4     2025         5                  Chelsea       8           4        2
# 5     2025         6                  Everton       7           4        2
# 6     2025         7               Sunderland       7           4        2
# 7     2025         8          Manchester City       6           4        2
# 8     2025         9           Crystal Palace       6           4        1
# 9     2025        10         Newcastle United       5           4        1
# 10    2025        11                   Fulham       5           4        1
# 11    2025        12                Brentford       4           4        1
# 12    2025        13   Brighton & Hove Albion       4           4        1
# 13    2025        14        Manchester United       4           4        1
# 14    2025        15        Nottingham Forest       4           4        1
# 15    2025        16             Leeds United       4           4        1
# 16    2025        17                  Burnley       3           4        1
# 17    2025        18          West Ham United       3           4        1
# 18    2025        19              Aston Villa       2           4        0
# 19    2025        20  Wolverhampton Wanderers       0           4        0
#
#     all_draw  all_lose  all_goals_for  all_goals_against  goal_diff  \
# 0          0         0              9                  4          5
# 1          0         1              9                  1          8
# 2          0         1              8                  1          7
# 3          0         1              6                  5          1
# 4          2         0              9                  3          6
# 5          1         1              5                  3          2
# 6          1         1              5                  3          2
# 7          0         2              8                  4          4
# 8          3         0              4                  1          3
# 9          2         1              3                  3          0
# 10         2         1              3                  4         -1
# 11         1         2              5                  7         -2
# 12         1         2              4                  6         -2
# 13         1         2              4                  7         -3
# 14         1         2              4                  8         -4
# 15         1         2              1                  6         -5
# 16         0         3              4                  7         -3
# 17         0         3              4                 11         -7
# 18         2         2              0                  4         -4
# 19         0         4              2                  9         -7
#
#                                                  logo
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 5   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 6   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 7   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 8   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 9   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 10  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 11  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 12  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 13  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 14  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 15  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 16  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 17  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 18  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 19  https://a.espncdn.com/i/teamlogos/soccer/500/3...

# %%
df.info
# Out:
# <bound method DataFrame.info of     season  position                     team  points  all_played  all_win  \
# 0     2025         1                Liverpool      12           4        4
# 1     2025         2                  Arsenal       9           4        3
# 2     2025         3        Tottenham Hotspur       9           4        3
# 3     2025         4          AFC Bournemouth       9           4        3
# 4     2025         5                  Chelsea       8           4        2
# 5     2025         6                  Everton       7           4        2
# 6     2025         7               Sunderland       7           4        2
# 7     2025         8          Manchester City       6           4        2
# 8     2025         9           Crystal Palace       6           4        1
# 9     2025        10         Newcastle United       5           4        1
# 10    2025        11                   Fulham       5           4        1
# 11    2025        12                Brentford       4           4        1
# 12    2025        13   Brighton & Hove Albion       4           4        1
# 13    2025        14        Manchester United       4           4        1
# 14    2025        15        Nottingham Forest       4           4        1
# 15    2025        16             Leeds United       4           4        1
# 16    2025        17                  Burnley       3           4        1
# 17    2025        18          West Ham United       3           4        1
# 18    2025        19              Aston Villa       2           4        0
# 19    2025        20  Wolverhampton Wanderers       0           4        0
#
#     all_draw  all_lose  all_goals_for  all_goals_against  goal_diff  \
# 0          0         0              9                  4          5
# 1          0         1              9                  1          8
# 2          0         1              8                  1          7
# 3          0         1              6                  5          1
# 4          2         0              9                  3          6
# 5          1         1              5                  3          2
# 6          1         1              5                  3          2
# 7          0         2              8                  4          4
# 8          3         0              4                  1          3
# 9          2         1              3                  3          0
# 10         2         1              3                  4         -1
# 11         1         2              5                  7         -2
# 12         1         2              4                  6         -2
# 13         1         2              4                  7         -3
# 14         1         2              4                  8         -4
# 15         1         2              1                  6         -5
# 16         0         3              4                  7         -3
# 17         0         3              4                 11         -7
# 18         2         2              0                  4         -4
# 19         0         4              2                  9         -7
#
#                                                  logo
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 3   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 4   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 5   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 6   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 7   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 8   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 9   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 10  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 11  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 12  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 13  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 14  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 15  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 16  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 17  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 18  https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 19  https://a.espncdn.com/i/teamlogos/soccer/500/3...  >

# %% [markdown]
# ---LOAD---

# %%
MYSQL_HOST = os.getenv("MYSQL_HOST")
MYSQL_USER = os.getenv("MYSQL_USER")
MYSQL_PASSWORD = os.getenv("MYSQL_PASSWORD")
MYSQL_DATABASE = os.getenv("MYSQL_DATABASE")
MYSQL_PORT = os.getenv("MYSQL_PORT")

# %%
#cursor.close()
#server_conn.close()

# %%
# Set MYSQL_USER if not set
if not MYSQL_USER:
    MYSQL_USER = "pl_app_writer"  

db_connection = connector.connect(
    host=MYSQL_HOST,
    port=MYSQL_PORT,
    user=MYSQL_USER,
    password=MYSQL_PASSWORD,
    database=MYSQL_DATABASE,
    connection_timeout=15,
    autocommit=False,
    raise_on_warnings=True
)

cur = db_connection.cursor()
print(f"[SUCCESS] Connection to MySQL DB '{MYSQL_DATABASE}' was successful.")
# Out:
# [SUCCESS] Connection to MySQL DB 'premier_league_db' was successful.

# %%
sql_table = "standings"
cur.execute(f"SHOW TABLES LIKE '{sql_table}'")

if cur.fetchone() is None:
    raise SystemExit(f"[ERROR] Table '{sql_table}' does not exist in DB '{MYSQL_DATABASE}'")
else:
    print(f"[SUCCESS] Table '{sql_table}' exists in DB '{MYSQL_DATABASE}'")
# Out:
# [SUCCESS] Table 'standings' exists in DB 'premier_league_db'

# %%
#Start the UPESERT operation

table_cols = [ "season", "position", "team", "points",
    "all_played", "all_win", "all_draw", "all_lose",
    "all_goals_for", "all_goals_against", "goal_diff", "logo"]

standings_df = df[table_cols]

# %%
standings_records_tuples = standings_df.itertuples(index=False, name=None)

list_ofstandings_records_tuples = list(standings_records_tuples)

# %%
UPSERT_SQL = f"""
INSERT INTO {sql_table} (season, position, team, points,
    all_played, all_win, all_draw, all_lose, all_goals_for, all_goals_against, goal_diff, logo)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
ON DUPLICATE KEY UPDATE
    position = VALUES(position),
    points = VALUES(points),
    all_played = VALUES(all_played),
    all_win = VALUES(all_win),
    all_draw = VALUES(all_draw),
    all_lose = VALUES(all_lose),
    all_goals_for = VALUES(all_goals_for),
    all_goals_against = VALUES(all_goals_against),
    goal_diff = VALUES(goal_diff),
    logo = VALUES(logo)
"""

# %%
no_of_records = len(list_ofstandings_records_tuples)

# %%
try:
    cur.executemany(UPSERT_SQL, list_ofstandings_records_tuples)
    db_connection.commit()
    print(f"[SUCCESS] UPSERT operation completed successfully. {no_of_records} records processed.")
except connector.Error as e:
    db_connection.rollback()
    print(f"[ERROR] UPSERT operation failed: {e}")
finally:
    cur.close()
    db_connection.close()
    print(f"All database connections closed.")
# Out:
# All database connections closed.
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\khsel\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\cursor_cext.py:457, in CMySQLCursor.executemany(self, operation, seq_params)
#     456     if not self._connection:
# --> 457         raise ProgrammingError
#     458 except (ProgrammingError, ReferenceError) as err:
#
# ProgrammingError: Unknown error
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[148], line 2
#       1 try:
# ----> 2     cur.executemany(UPSERT_SQL, list_ofstandings_records_tuples)
#       3     db_connection.commit()
#
# File c:\Users\khsel\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\cursor_cext.py:459, in CMySQLCursor.executemany(self, operation, seq_params)
#     458 except (ProgrammingError, ReferenceError) as err:
# --> 459     raise ProgrammingError("Cursor is not connected") from err
#     460 self._connection.handle_unread_result()
#
# ProgrammingError: Cursor is not connected
#
# During handling of the above exception, another exception occurred:
#
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[148], line 6
#       4     print(f"[SUCCESS] UPSERT operation completed successfully. {no_of_records} records processed.")
#       5 except connector.Error as e:
# ----> 6     db_connection.rollback()
#       7     print(f"[ERROR] UPSERT operation failed: {e}")
#       8 finally:
#
# File c:\Users\khsel\AppData\Local\Programs\Python\Python312\Lib\site-packages\mysql\connector\connection_cext.py:611, in CMySQLConnection.rollback(self)
#     609 if self._cmysql:
#     610     self._cmysql.consume_result()
# --> 611     self._cmysql.rollback()
#
# MySQLInterfaceError: MySQL server has gone away
